# %%
import pandas as pd
import numpy as np
from neuralprophet import NeuralProphet, set_random_seed
import joblib

# %%
set_random_seed(0)

# %%
# import dataser from csv file
train = pd.read_csv('../Data/train.csv')
test = pd.read_csv('../Data/test.csv')

# %%
# importar ../Data/DatosCicloAprovisionamiento.xlsx
df_ciclo = pd.read_excel('../Data/DatosCicloAprovisionamiento.xlsx')
df_ciclo = df_ciclo.sort_values(by=['sku']).reset_index(drop=True)
df_ciclo = df_ciclo.rename(columns={'sku': 'idSku'})
df_ciclo['ciclo_aprovisionamiento'] = df_ciclo['diasEntrePedidos'] + df_ciclo['diasLeadtime']
df_ciclo.head()
# Out:
#    idSku  diasEntrePedidos  diasLeadtime  ciclo_aprovisionamiento
# 0      1                18             2                       20
# 1      2                28             4                       32
# 2      3                28             2                       30
# 3      4                14             2                       16
# 4      5                14             4                       18

# %%
def grid_search(train_1, n_forecasts):
    seasonality_mode = ['multiplicative'] #['multiplicative', 'additive']

    n_changepoints = [10, 100]
    trend_reg = [0] # [0, 0.1]
    n_lags = [1, 7, 14]
    num_hidden_layers = [0, 2]

    # create empty dataframe to store results
    results = pd.DataFrame(columns=['seasonality_mode', 'n_changepoints', 'trend_reg', 'n_lags', 'num_hidden_layers', 'rmse'])
    # grid search
    for mode in seasonality_mode:
        for n_cp in n_changepoints:
            for reg in trend_reg:
                for n_lag in n_lags:
                    for n_layer in num_hidden_layers:
                        m = NeuralProphet(seasonality_mode=mode, n_forecasts=n_forecasts, n_changepoints=n_cp, trend_reg=reg, n_lags=n_lag, num_hidden_layers=n_layer)
                        m.fit(train_1, freq="D")
                        rmse = m.test(train_1)['RMSE'][0]
                        results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
    return results

# %%
# create empty dataframe to store best results for each sku
best_results = pd.DataFrame(columns=['idSku', 'seasonality_mode', 'n_changepoints', 'trend_reg', 'n_lags', 'num_hidden_layers', 'rmse'])

# %%
# list distinct values of idSku
skus = train['idSku'].unique()
for s in skus:
    train_s = train[train['idSku'] == s]
    train_s = train_s[['idSecuencia', 'udsVenta']]
    train_s = train_s.rename(columns={'idSecuencia': 'ds', 'udsVenta': 'y'})
    n_forecasts = df_ciclo[df_ciclo['idSku'] == s]['ciclo_aprovisionamiento'].values[0]
    results = grid_search(train_s, n_forecasts)
    best_result = results[results['rmse'] == results['rmse'].min()]
    best_result['idSku'] = s
    best_results = best_results.append(best_result, ignore_index=True)
    # fit the model with the parameter values of the best model
    best_m = NeuralProphet(seasonality_mode=best_result['seasonality_mode'].values[0], n_forecasts=n_forecasts, n_changepoints=best_result['n_changepoints'].values[0],
    trend_reg=best_result['trend_reg'].values[0], n_lags=best_result['n_lags'].values[0], num_hidden_layers=best_result['num_hidden_layers'].values[0])
    best_m.fit(train_s, freq="D")
    # save the model
    path = '../Neural_prophet_models/neural_prophet_' + str(s) + '.pkl'
    joblib.dump(best_m, path)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 248
#  90%|████████▉ | 107/119 [00:00<00:00, 202.85it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.04E-01, min: 1.48E+00
#  91%|█████████ | 108/119 [00:00<00:00, 181.43it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.04E-01, min: 2.10E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 2.10E-01
# Epoch[248/248]: 100%|██████████| 248/248 [00:14<00:00, 17.46it/s, SmoothL1Loss=0.0305, MAE=6.05, RMSE=8.15, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.031  6.048  8.156
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 248
#  95%|█████████▍| 113/119 [00:00<00:00, 210.62it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 6.26E-02, min: 1.73E+01
#  96%|█████████▌| 114/119 [00:00<00:00, 175.02it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 7.46E-02, min: 2.10E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 7.76E-02
# Epoch[248/248]: 100%|██████████| 248/248 [00:18<00:00, 13.72it/s, SmoothL1Loss=0.0306, MAE=6.03, RMSE=8.15, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.031  6.029  8.158
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 249
#  95%|█████████▍| 113/119 [00:00<00:00, 287.79it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 6.26E-02, min: 2.50E+00
#  97%|█████████▋| 115/119 [00:00<00:00, 316.38it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 6.26E-02, min: 6.02E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 7.32E-02
# Epoch[249/249]: 100%|██████████| 249/249 [00:14<00:00, 17.48it/s, SmoothL1Loss=0.0303, MAE=6.1, RMSE=8.12, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.030  6.100  8.130
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 249
#  92%|█████████▏| 110/119 [00:00<00:00, 237.54it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.90E-02, min: 6.14E-01
#  94%|█████████▍| 112/119 [00:00<00:00, 279.88it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 7.46E-02, min: 6.14E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 8.72E-02
# Epoch[249/249]: 100%|██████████| 249/249 [00:18<00:00, 13.52it/s, SmoothL1Loss=0.0306, MAE=6.03, RMSE=8.16, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.031  6.032  8.163
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 251
#  98%|█████████▊| 117/119 [00:00<00:00, 231.38it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.70E-02, min: 1.24E+00
#  99%|█████████▉| 118/119 [00:00<00:00, 222.34it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.70E-02, min: 1.24E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 5.15E-02
# Epoch[251/251]: 100%|██████████| 251/251 [00:13<00:00, 18.15it/s, SmoothL1Loss=0.0301, MAE=6.16, RMSE=8.09, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.030  6.164  8.094
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 251
#  89%|████████▉ | 106/119 [00:00<00:00, 156.84it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.26E-01, min: 3.63E-01
#  90%|████████▉ | 107/119 [00:00<00:00, 203.30it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 4.24E+00, min: 2.55E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 3.77E-01
# Epoch[251/251]: 100%|██████████| 251/251 [00:17<00:00, 14.37it/s, SmoothL1Loss=0.0307, MAE=6.05, RMSE=8.17, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.031  6.050  8.180
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 248
#  96%|█████████▌| 114/119 [00:01<00:00, 113.43it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.90E-02, min: 2.10E+00
#  98%|█████████▊| 117/119 [00:00<00:00, 133.98it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.90E-02, min: 2.50E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 9.25E-02
# Epoch[248/248]: 100%|██████████| 248/248 [00:16<00:00, 15.49it/s, SmoothL1Loss=0.0255, MAE=5.45, RMSE=7.44, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.025  5.452  7.447
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 248
#  96%|█████████▌| 114/119 [00:01<00:00, 98.93it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.26E-01, min: 1.24E+00
#  96%|█████████▌| 114/119 [00:01<00:00, 105.25it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.26E-01, min: 6.14E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 1.17E-01
# Epoch[248/248]: 100%|██████████| 248/248 [00:21<00:00, 11.50it/s, SmoothL1Loss=0.0249, MAE=5.38, RMSE=7.35, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.025  5.380  7.362
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 249
#  92%|█████████▏| 110/119 [00:00<00:00, 124.61it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 2.60E-02, min: 4.24E+00
#  92%|█████████▏| 110/119 [00:00<00:00, 144.93it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 2.18E-02, min: 2.10E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 3.84E-02
# Epoch[249/249]: 100%|██████████| 249/249 [00:15<00:00, 16.19it/s, SmoothL1Loss=0.0259, MAE=5.57, RMSE=7.5, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.026  5.567  7.513
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 249
#  92%|█████████▏| 110/119 [00:00<00:00, 127.13it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 4.41E-02, min: 8.55E+00
#  92%|█████████▏| 109/119 [00:00<00:00, 113.15it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.70E-02, min: 5.15E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 5.46E-02
# Epoch[249/249]: 100%|██████████| 249/249 [00:18<00:00, 13.33it/s, SmoothL1Loss=0.025, MAE=5.44, RMSE=7.37, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.025  5.436  7.384
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 251
#  95%|█████████▍| 113/119 [00:00<00:00, 121.86it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.10E-02, min: 1.24E+00
#  92%|█████████▏| 110/119 [00:00<00:00, 135.26it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.10E-02, min: 1.24E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 4.58E-02
# Epoch[251/251]: 100%|██████████| 251/251 [00:15<00:00, 16.31it/s, SmoothL1Loss=0.0252, MAE=5.52, RMSE=7.41, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.025  5.522  7.414
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 251
#  89%|████████▉ | 106/119 [00:00<00:00, 117.57it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.24E+00, min: 4.32E-01
#  90%|████████▉ | 107/119 [00:00<00:00, 120.82it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.26E-01, min: 3.04E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 2.50E-01
# Epoch[251/251]: 100%|██████████| 251/251 [00:19<00:00, 13.21it/s, SmoothL1Loss=0.0238, MAE=5.26, RMSE=7.2, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.024  5.259  7.207
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\110840151.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_result['idSku'] = s
#
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\110840151.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_results = best_results.append(best_result, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 251
#  90%|████████▉ | 107/119 [00:00<00:00, 111.90it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 4.49E-03, min: 1.48E+00
#  90%|████████▉ | 107/119 [00:00<00:00, 116.45it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 4.49E-03, min: 6.14E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 1.26E-02
# Epoch[251/251]: 100%|██████████| 251/251 [00:18<00:00, 13.55it/s, SmoothL1Loss=0.0188, MAE=4.87, RMSE=6.4, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 250
#  93%|█████████▎| 111/119 [00:00<00:00, 243.09it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.04E+00, min: 1.06E-01
#  95%|█████████▍| 113/119 [00:00<00:00, 174.97it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 2.50E+00, min: 1.06E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 6.38E-01
# Epoch[250/250]: 100%|██████████| 250/250 [00:13<00:00, 17.94it/s, SmoothL1Loss=0.025, MAE=6.8, RMSE=9.39, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.025  6.803  9.396
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 250
#  91%|█████████ | 108/119 [00:00<00:00, 191.13it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 7.61E-03, min: 6.14E-01
#  87%|████████▋ | 104/119 [00:00<00:00, 168.35it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.56E+00, min: 3.04E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 1.39E-01
# Epoch[250/250]: 100%|██████████| 250/250 [00:17<00:00, 13.96it/s, SmoothL1Loss=0.025, MAE=6.79, RMSE=9.39, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.025  6.792  9.399
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 252
#  93%|█████████▎| 110/118 [00:00<00:00, 168.84it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 5.88E-02, min: 1.19E+00
#  92%|█████████▏| 109/118 [00:00<00:00, 208.49it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 5.88E-02, min: 2.03E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 7.02E-02
# Epoch[252/252]: 100%|██████████| 252/252 [00:17<00:00, 14.62it/s, SmoothL1Loss=0.0247, MAE=6.82, RMSE=9.32, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.025  6.823  9.330
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 252
#  91%|█████████ | 107/118 [00:00<00:00, 169.26it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.38E-03, min: 4.12E+00
#  92%|█████████▏| 108/118 [00:00<00:00, 179.36it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.38E-03, min: 4.12E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 1.91E-02
# Epoch[252/252]: 100%|██████████| 252/252 [00:20<00:00, 12.43it/s, SmoothL1Loss=0.0186, MAE=6.16, RMSE=8.09, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.019  6.164  8.095
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 253
#  97%|█████████▋| 114/118 [00:00<00:00, 200.08it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 2.42E-02, min: 2.42E+00
#  97%|█████████▋| 114/118 [00:00<00:00, 196.50it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 2.42E-02, min: 1.43E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 3.89E-02
# Epoch[253/253]: 100%|██████████| 253/253 [00:15<00:00, 16.24it/s, SmoothL1Loss=0.0244, MAE=6.85, RMSE=9.27, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.024  6.848  9.279
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 253
#  94%|█████████▍| 111/118 [00:00<00:00, 157.52it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.38E-02, min: 8.38E-01
#  94%|█████████▍| 111/118 [00:00<00:00, 175.72it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 4.92E-02, min: 7.02E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 7.44E-02
# Epoch[253/253]: 100%|██████████| 253/253 [00:20<00:00, 12.59it/s, SmoothL1Loss=0.0249, MAE=6.78, RMSE=9.37, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.025  6.784  9.380
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 250
#  97%|█████████▋| 116/119 [00:01<00:00, 90.57it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.06E-01, min: 5.05E+00
#  97%|█████████▋| 115/119 [00:01<00:00, 85.34it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.06E-01, min: 3.56E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 1.04E-01
# Epoch[250/250]: 100%|██████████| 250/250 [00:26<00:00,  9.53it/s, SmoothL1Loss=0.0221, MAE=6.28, RMSE=8.81, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.022  6.281  8.824
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 250
#  92%|█████████▏| 109/119 [00:01<00:00, 80.86it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.06E-01, min: 6.14E-01
#  90%|████████▉ | 107/119 [00:01<00:00, 79.78it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.06E-01, min: 2.50E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 1.04E-01
# Epoch[250/250]: 100%|██████████| 250/250 [00:32<00:00,  7.64it/s, SmoothL1Loss=0.0208, MAE=6.06, RMSE=8.56, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.021  6.059  8.566
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 252
# 100%|██████████| 118/118 [00:01<00:00, 99.42it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.38E-02, min: 4.92E+00
#  99%|█████████▉| 117/118 [00:01<00:00, 85.71it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.38E-02, min: 4.12E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 8.89E-02
# Epoch[252/252]: 100%|██████████| 252/252 [00:25<00:00, 10.00it/s, SmoothL1Loss=0.0218, MAE=6.33, RMSE=8.76, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.022  6.326  8.775
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 252
#  96%|█████████▌| 113/118 [00:01<00:00, 87.39it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.43E-02, min: 2.03E+00
#  93%|█████████▎| 110/118 [00:01<00:00, 92.46it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.70E-02, min: 5.88E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 2.89E-02
# Epoch[252/252]: 100%|██████████| 252/252 [00:29<00:00,  8.55it/s, SmoothL1Loss=0.0169, MAE=5.84, RMSE=7.72, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.017  5.843  7.724
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 253
#  95%|█████████▍| 112/118 [00:01<00:00, 97.56it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 2.42E-02, min: 5.88E-01
#  92%|█████████▏| 108/118 [00:01<00:00, 105.27it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 2.42E-02, min: 5.88E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 3.89E-02
# Epoch[253/253]: 100%|██████████| 253/253 [00:26<00:00,  9.50it/s, SmoothL1Loss=0.0212, MAE=6.3, RMSE=8.65, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.021  6.303  8.655
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 253
#  86%|████████▋ | 102/118 [00:01<00:00, 82.17it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.19E-01, min: 1.00E+00
#  89%|████████▉ | 105/118 [00:01<00:00, 76.78it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.00E-01, min: 8.38E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 1.06E-01
# Epoch[253/253]: 100%|██████████| 253/253 [00:33<00:00,  7.64it/s, SmoothL1Loss=0.0205, MAE=6.02, RMSE=8.49, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.020  6.017  8.501
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.043  2.670  3.511
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 251
#  88%|████████▊ | 105/119 [00:01<00:00, 94.33it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 9.07E-03, min: 1.76E+00
#  88%|████████▊ | 105/119 [00:00<00:00, 136.59it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 9.07E-03, min: 2.10E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 2.02E-02
# Epoch[251/251]: 100%|██████████| 251/251 [00:26<00:00,  9.45it/s, SmoothL1Loss=0.0274, MAE=2.14, RMSE=2.8, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.027  2.140  2.808
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 248
#  92%|█████████▏| 110/119 [00:01<00:00, 75.45it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.04E-01, min: 1.24E+00
#  94%|█████████▍| 112/119 [00:01<00:00, 71.42it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.04E-01, min: 1.24E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 2.10E-01
# Epoch[248/248]: 100%|██████████| 248/248 [00:24<00:00,  9.98it/s, SmoothL1Loss=0.0374, MAE=2.45, RMSE=3.27, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.037  2.447  3.280
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 248
#  97%|█████████▋| 116/119 [00:01<00:00, 63.23it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.70E-02, min: 1.02E+01
#  97%|█████████▋| 115/119 [00:01<00:00, 87.32it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.70E-02, min: 8.55E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 5.15E-02
# Epoch[248/248]: 100%|██████████| 248/248 [00:30<00:00,  8.10it/s, SmoothL1Loss=0.04, MAE=2.57, RMSE=3.39, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.040  2.569  3.394
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 249
#  92%|█████████▏| 109/119 [00:01<00:00, 67.70it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 2.55E-01, min: 1.04E+00
#  93%|█████████▎| 111/119 [00:01<00:00, 87.39it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 5.15E-01, min: 1.04E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 2.36E-01
# Epoch[249/249]: 100%|██████████| 249/249 [00:24<00:00, 10.22it/s, SmoothL1Loss=0.0371, MAE=2.47, RMSE=3.26, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.037  2.466  3.269
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 249
#  92%|█████████▏| 109/119 [00:01<00:00, 77.24it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.55E+00, min: 3.56E+00
#  92%|█████████▏| 109/119 [00:01<00:00, 67.49it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.83E-02, min: 3.56E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 2.50E-01
# Epoch[249/249]: 100%|██████████| 249/249 [00:31<00:00,  7.98it/s, SmoothL1Loss=0.0374, MAE=2.45, RMSE=3.28, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.037  2.448  3.282
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 251
#  95%|█████████▍| 113/119 [00:01<00:00, 69.97it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 6.26E-02, min: 2.10E+00
#  95%|█████████▍| 113/119 [00:01<00:00, 66.11it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 6.26E-02, min: 2.10E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 7.32E-02
# Epoch[251/251]: 100%|██████████| 251/251 [00:24<00:00, 10.37it/s, SmoothL1Loss=0.0379, MAE=2.51, RMSE=3.29, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.038  2.513  3.302
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 251
#  93%|█████████▎| 111/119 [00:01<00:00, 70.06it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.22E+01, min: 7.32E-01
#  92%|█████████▏| 109/119 [00:01<00:00, 62.07it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.24E+00, min: 8.72E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 1.15E+00
# Epoch[251/251]: 100%|██████████| 251/251 [00:31<00:00,  8.05it/s, SmoothL1Loss=0.0383, MAE=2.48, RMSE=3.31, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.038  2.476  3.319
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\3284685260.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'seasonality_mode': mode, 'n_changepoints': n_cp, 'trend_reg': reg, 'n_lags': n_lag, 'num_hidden_layers': n_layer, 'rmse': rmse}, ignore_index=True)
#
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\110840151.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_result['idSku'] = s
#
# WARNING - (py.warnings._showwarnmsg) - C:\Users\96gar\AppData\Local\Temp\ipykernel_22204\110840151.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_results = best_results.append(best_result, ignore_index=True)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.804% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 251
#  92%|█████████▏| 109/119 [00:01<00:00, 104.95it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 7.46E-02, min: 7.32E-01
#  90%|████████▉ | 107/119 [00:01<00:00, 105.01it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.90E-02, min: 1.76E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 8.72E-02
# Epoch[251/251]: 100%|██████████| 251/251 [00:26<00:00,  9.31it/s, SmoothL1Loss=0.0436, MAE=2.63, RMSE=3.54, RegLoss=0]

# %%
best_results
# Out:
#    idSku seasonality_mode n_changepoints trend_reg n_lags num_hidden_layers  \
# 0      1   multiplicative            100         0     14                 2
# 1      2   multiplicative            100         0      7                 2
# 2      3   multiplicative            100         0     14                 2
# 3      4   multiplicative             10         0     14                 2
# 4      5   multiplicative            100         0     14                 2
# 5      6   multiplicative            100         0      1                 0
# 6      7   multiplicative            100         0      7                 2
# 7      8   multiplicative            100         0     14                 2
# 8      9   multiplicative            100         0      7                 2
# 9     10   multiplicative            100         0     14                 0
# 10    11   multiplicative             10         0     14                 2
# 11    12   multiplicative             10         0     14                 2
# 12    13   multiplicative            100         0      7                 2
# 13    14   multiplicative            100         0     14                 2
# 14    15   multiplicative             10         0     14                 2
# 15    16   multiplicative            100         0      7                 0
# 16    17   multiplicative            100         0      7                 2
# 17    18   multiplicative            100         0      7                 2
# 18    19   multiplicative             10         0     14                 2
# 19    20   multiplicative            100         0      7                 2
# 20    21   multiplicative            100         0     14                 2
# 21    22   multiplicative            100         0     14                 0
# 22    23   multiplicative            100         0     14                 2
# 23    24   multiplicative            100         0      1                 2
# 24    25   multiplicative            100         0     14                 2
# 25    26   multiplicative            100         0      7                 2
# 26    27   multiplicative            100         0     14                 2
# 27    28   multiplicative             10         0     14                 2
# 28    29   multiplicative            100         0      7                 2
# 29    30   multiplicative            100         0     14                 2
# 30    31   multiplicative            100         0     14                 2
# 31    32   multiplicative            100         0     14                 2
# 32    33   multiplicative            100         0      7                 2
# 33    34   multiplicative            100         0      7                 2
# 34    35   multiplicative            100         0     14                 2
# 35    36   multiplicative            100         0      7                 2
# 36    37   multiplicative             10         0     14                 2
# 37    38   multiplicative            100         0      7                 2
# 38    39   multiplicative            100         0      7                 2
# 39    40   multiplicative             10         0     14                 2
# 40    41   multiplicative            100         0     14                 2
# 41    42   multiplicative             10         0      7                 2
# 42    43   multiplicative            100         0     14                 2
# 43    44   multiplicative            100         0     14                 0
# 44    45   multiplicative             10         0     14                 2
# 45    46   multiplicative            100         0     14                 2
# 46    47   multiplicative            100         0      7                 2
# 47    48   multiplicative            100         0      7                 2
# 48    49   multiplicative            100         0      7                 2
# 49    50   multiplicative             10         0     14                 2
#
#         rmse
# 0   7.207204
# 1    7.72415
# 2   5.886485
# 3   4.498294
# 4   6.029702
# 5   6.660328
# 6   4.157397
# 7   3.431296
# 8   4.517002
# 9   4.074048
# 10  3.434735
# 11  3.537057
# 12  3.751586
# 13  3.461943
# 14  5.756577
# 15  4.604636
# 16  4.093891
# 17  4.114496
# 18  3.175934
# 19  3.478026
# 20   2.94517
# 21  3.070866
# 22  2.962654
# 23  5.228109
# 24  2.729931
# 25  3.762303
# 26  3.446112
# 27  3.601003
# 28  4.088595
# 29  3.136181
# 30  3.625482
# 31  3.817274
# 32  2.875307
# 33  3.309145
# 34  2.869469
# 35  3.173894
# 36  2.905444
# 37  2.934667
# 38  3.793402
# 39  3.376064
# 40  3.118593
# 41  3.554761
# 42  4.272871
# 43  3.361506
# 44  3.893478
# 45  3.570041
# 46  5.178525
# 47  2.794012
# 48  3.154132
# 49  2.807593

# %%
# save the best results
best_results.to_csv('../Data/NP_best_models.csv', index=False)
